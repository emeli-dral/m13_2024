# %% [markdown]
# ## NYC Taxi Data Experimnt Tracking

# %%
xgb.config(verbo)
# Out:
# Type:        module
# String form: <module 'xgboost.config' from '/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/xgboost/config.py'>
# File:        /opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/xgboost/config.py
# Source:
# # pylint: disable=missing-function-docstring
# """Global configuration for XGBoost"""
# import ctypes
# import json
# from contextlib import contextmanager
# from functools import wraps
# from typing import Any, Callable, Dict, Iterator, Optional, cast
#
# from ._typing import _F
# from .core import _LIB, _check_call, c_str, py_str
#
#
# def config_doc(
#     *,
#     header: Optional[str] = None,
#     extra_note: Optional[str] = None,
#     parameters: Optional[str] = None,
#     returns: Optional[str] = None,
#     see_also: Optional[str] = None,
# ) -> Callable[[_F], _F]:
#     """Decorator to format docstring for config functions.
#
#     Parameters
#     ----------
#     header: str
#         An introducion to the function
#     extra_note: str
#         Additional notes
#     parameters: str
#         Parameters of the function
#     returns: str
#         Return value
#     see_also: str
#         Related functions
#     """
#
#     doc_template = """
#     {header}
#
#     Global configuration consists of a collection of parameters that can be applied in the
#     global scope. See :ref:`global_config` for the full list of parameters supported in
#     the global configuration.
#
#     {extra_note}
#
#     .. versionadded:: 1.4.0
#     """
#
#     common_example = """
#     Example
#     -------
#
#     .. code-block:: python
#
#         import xgboost as xgb
#
#         # Show all messages, including ones pertaining to debugging
#         xgb.set_config(verbosity=2)
#
#         # Get current value of global configuration
#         # This is a dict containing all parameters in the global configuration,
#         # including 'verbosity'
#         config = xgb.get_config()
#         assert config['verbosity'] == 2
#
#         # Example of using the context manager xgb.config_context().
#         # The context manager will restore the previous value of the global
#         # configuration upon exiting.
#         with xgb.config_context(verbosity=0):
#             # Suppress warning caused by model generated with XGBoost version < 1.0.0
#             bst = xgb.Booster(model_file='./old_model.bin')
#         assert xgb.get_config()['verbosity'] == 2  # old value restored
#
#     Nested configuration context is also supported:
#
#     Example
#     -------
#
#     .. code-block:: python
#
#         with xgb.config_context(verbosity=3):
#             assert xgb.get_config()["verbosity"] == 3
#             with xgb.config_context(verbosity=2):
#                 assert xgb.get_config()["verbosity"] == 2
#
#         xgb.set_config(verbosity=2)
#         assert xgb.get_config()["verbosity"] == 2
#         with xgb.config_context(verbosity=3):
#             assert xgb.get_config()["verbosity"] == 3
#     """
#
#     def none_to_str(value: Optional[str]) -> str:
#         return "" if value is None else value
#
#     def config_doc_decorator(func: _F) -> _F:
#         func.__doc__ = (
#             doc_template.format(
#                 header=none_to_str(header), extra_note=none_to_str(extra_note)
#             )
#             + none_to_str(parameters)
#             + none_to_str(returns)
#             + none_to_str(common_example)
#             + none_to_str(see_also)
#         )
#
#         @wraps(func)
#         def wrap(*args: Any, **kwargs: Any) -> Any:
#             return func(*args, **kwargs)
#
#         return cast(_F, wrap)
#
#     return config_doc_decorator
#
#
# @config_doc(
#     header="""
#     Set global configuration.
#     """,
#     parameters="""
#     Parameters
#     ----------
#     new_config: Dict[str, Any]
#         Keyword arguments representing the parameters and their values
#             """,
# )
# def set_config(**new_config: Any) -> None:
#     not_none = {}
#     for k, v in new_config.items():
#         if v is not None:
#             not_none[k] = v
#     config = json.dumps(not_none)
#     _check_call(_LIB.XGBSetGlobalConfig(c_str(config)))
#
#
# @config_doc(
#     header="""
#     Get current values of the global configuration.
#     """,
#     returns="""
#     Returns
#     -------
#     args: Dict[str, Any]
#         The list of global parameters and their values
#             """,
# )
# def get_config() -> Dict[str, Any]:
#     config_str = ctypes.c_char_p()
#     _check_call(_LIB.XGBGetGlobalConfig(ctypes.byref(config_str)))
#     value = config_str.value
#     assert value
#     config = json.loads(py_str(value))
#     return config
#
#
# @contextmanager
# @config_doc(
#     header="""
#     Context manager for global XGBoost configuration.
#     """,
#     parameters="""
#     Parameters
#     ----------
#     new_config: Dict[str, Any]
#         Keyword arguments representing the parameters and their values
#             """,
#     extra_note="""
#     .. note::
#
#         All settings, not just those presently modified, will be returned to their
#         previous values when the context manager is exited. This is not thread-safe.
#             """,
#     see_also="""
#     See Also
#     --------
#     set_config: Set global XGBoost configuration
#     get_config: Get current values of the global configuration
#             """,
# )
# def config_context(**new_config: Any) -> Iterator[None]:
#     old_config = get_config().copy()
#     set_config(**new_config)
#
#     try:
#         yield
#     finally:
#         set_config(**old_config)

# %%
# !python -V

# %%
import requests
import pickle

import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.svm import LinearSVR

from tqdm import tqdm

# %%
! mkdir data

# %%
files = [('green_tripdata_2024-03.parquet', './data'), ('green_tripdata_2024-04.parquet', './data')]

print("Download files:")
for file, path in files:
    url=f"https://d37ci6vzurychx.cloudfront.net/trip-data/{file}"
    resp=requests.get(url, stream=True)
    save_path=f"{path}/{file}"
    with open(save_path, "wb") as handle:
        for data in tqdm(resp.iter_content(),
                        desc=f"{file}",
                        postfix=f"save to {save_path}",
                        total=int(resp.headers["Content-Length"])):
            handle.write(data)
# Out:
# Download files:
# green_tripdata_2024-03.parquet: 100%|█| 1372372/1372372 [00:03<00:00, 442488.81it/s, save
# green_tripdata_2024-04.parquet: 100%|█| 1346502/1346502 [00:03<00:00, 433990.51it/s, save

# %%
train_raw_data = pd.read_parquet('data/green_tripdata_2024-03.parquet')
val_raw_data = pd.read_parquet('data/green_tripdata_2024-04.parquet')

# %%
train_raw_data.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2024-03-01 00:10:52   2024-03-01 00:26:12                  N
# 1         2  2024-03-01 00:22:21   2024-03-01 00:35:15                  N
# 2         2  2024-03-01 00:45:27   2024-03-01 01:04:32                  N
# 3         1  2024-03-01 00:02:00   2024-03-01 00:23:45                  N
# 4         2  2024-03-01 00:16:45   2024-03-01 00:23:25                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           129           226              1.0           1.72
# 1         1.0           130           218              1.0           3.25
# 2         1.0           255           107              2.0           4.58
# 3         1.0           181            71              1.0           0.00
# 4         1.0            95           135              1.0           1.15
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0         12.8    1.0      0.5        3.06           0.0        NaN
# 1         17.7    1.0      0.5        0.00           0.0        NaN
# 2         23.3    1.0      0.5        3.50           0.0        NaN
# 3         22.5    0.0      1.5        0.00           0.0        NaN
# 4          8.6    1.0      0.5        1.00           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0         18.36           1.0        1.0
# 1                    1.0         20.20           2.0        1.0
# 2                    1.0         32.05           1.0        1.0
# 3                    1.0         24.00           1.0        1.0
# 4                    1.0         12.10           1.0        1.0
#
#    congestion_surcharge
# 0                  0.00
# 1                  0.00
# 2                  2.75
# 3                  0.00
# 4                  0.00

# %%
def process_dataframe(data):
    data.lpep_dropoff_datetime = pd.to_datetime(data.lpep_dropoff_datetime)
    data.lpep_pickup_datetime = pd.to_datetime(data.lpep_pickup_datetime)

    data['duration'] = data.lpep_dropoff_datetime - data.lpep_pickup_datetime
    data.duration = data.duration.apply(lambda td: td.total_seconds() / 60)
    data = data[(data.duration >= 1) & (data.duration <= 90)]
    
    data['PULocationID'].astype(str, copy=False)
    data['DOLocationID'].astype(str, copy=False)
    
    return data

# %%
num_features = ['trip_distance', 'extra', 'fare_amount']
cat_features = ['PULocationID', 'DOLocationID']

# %%
X_train = process_dataframe(train_raw_data)[num_features + cat_features]
X_val = process_dataframe(val_raw_data)[num_features + cat_features] 

y_train = process_dataframe(train_raw_data)['duration']
y_val = process_dataframe(val_raw_data)['duration']

# %%
X_val.isnull().sum()
# Out:
# trip_distance    0
# extra            0
# fare_amount      0
# PULocationID     0
# DOLocationID     0
# dtype: int64

# %% [markdown]
# ## Simple Experimnet

# %%
lr = Ridge()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 5.907885082410718

# %%
np.mean(y_pred)
# Out:
# 14.481896678592031

# %% [markdown]
# ## MLflow tracking

# %%
import mlflow

# %%
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("green_taxi")
# Out:
# <Experiment: artifact_location='/Users/emelidral/Dev/m13_2024/experiments/mlruns/1', creation_time=1721062613079, experiment_id='1', last_update_time=1721062613079, lifecycle_stage='active', name='green_taxi', tags={}>

# %%
# !ls -la  /Users/emelidral/Dev/m13_2024/experiments/mlruns/
# Out:
# total 0
# drwxr-xr-x  4 emelidral  staff  128 15 Jul 20:12 .
# drwxr-xr-x  8 emelidral  staff  256 16 Jul 12:47 ..
# drwxr-xr-x  2 emelidral  staff   64 15 Jul 20:12 .trash
# drwxr-xr-x  6 emelidral  staff  192 15 Jul 20:15 1

# %%
! pwd
# Out:
# /Users/emelidral/Dev/m13_2024/experiments

# %%
with mlflow.start_run():
    mlflow.set_tag("workspace", "inclass")
    mlflow.log_param("model_name", "Lasso")
    mlflow.log_param("train_data", "data/green_tripdata_2024-03.parquet")

    alpha = 0.05
    lr = Lasso(alpha=alpha)

    mlflow.log_param("alpha", alpha)
    
    lr.fit(X_train, y_train)
    y_pred = lr.predict(X_val)

    rmse = mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)

# %%
from hyperopt import fmin, tpe, hp
best = fmin(fn=lambda x: x ** 2,
    space=hp.uniform('x', -10, 10),
    algo=tpe.suggest,
    max_evals=100)
print(best)
# Out:
# 100%|███████████| 100/100 [00:00<00:00, 2156.55trial/s, best loss: 1.3992400834395533e-05]
# {'x': 0.0037406417677178783}

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages (2.1.0)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages (from xgboost) (1.13.1)

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
validation = xgb.DMatrix(X_val, label=y_val)

# %%
validation.get_label()
# Out:
# array([16.666666,  9.9     , 11.166667, ..., 11.2     , 12.      ,
#         7.      ], dtype=float32)

# %%
grid_search = {
    'max_depth':scope.int(hp.quniform('max_depth', 4, 50, 1)),
    'reg_alpha':hp.loguniform('reg_alpha', -5, -1)
}

# %%
def objective(params):
    with mlflow.start_run():
        num_boost_round = 100
        early_stopping_rounds = 50
        mlflow.log_param('num_boost_round', num_boost_round) 
        mlflow.log_param('early_stopping_rounds', early_stopping_rounds) 
        mlflow.log_params(params)
        
        booster = xgb.train(
            params=params,
            dtrain=train,
            evals=[(validation, "validation")],
            num_boost_round=num_boost_round,
            early_stopping_rounds=early_stopping_rounds  
        )

        y_pred = booster.predict(validation)
        rmse = mean_squared_error(y_val, y_pred)
        mlflow.log_metric('rmse', rmse)
        return {'loss':rmse, 'status':STATUS_OK}

# %%
best = fmin(
    fn = objective,
    space=grid_search,
    algo=tpe.suggest,
    max_evals=10,
    trials = Trials())
# Out:
# [0]	validation-rmse:7.66969
# [1]	validation-rmse:6.10889
# [2]	validation-rmse:5.19475
# [3]	validation-rmse:4.66806
# [4]	validation-rmse:4.38434
# [5]	validation-rmse:4.25302
# [6]	validation-rmse:4.20246
# [7]	validation-rmse:4.18548
# [8]	validation-rmse:4.19285
# [9]	validation-rmse:4.20390
# [10]	validation-rmse:4.21793
# [11]	validation-rmse:4.22992
# [12]	validation-rmse:4.24321
# [13]	validation-rmse:4.25282
# [14]	validation-rmse:4.25813
# [15]	validation-rmse:4.26452
# [16]	validation-rmse:4.27196
# [17]	validation-rmse:4.27642
# [18]	validation-rmse:4.28078
# [19]	validation-rmse:4.28395
# [20]	validation-rmse:4.28687
# [21]	validation-rmse:4.28985
# [22]	validation-rmse:4.29232
# [23]	validation-rmse:4.29453
# [24]	validation-rmse:4.29602
# [25]	validation-rmse:4.29737
# [26]	validation-rmse:4.29829
# [27]	validation-rmse:4.29946
# [28]	validation-rmse:4.30040
# [29]	validation-rmse:4.30111
# [30]	validation-rmse:4.30159
# [31]	validation-rmse:4.30209
# [32]	validation-rmse:4.30246
# [33]	validation-rmse:4.30275
# [34]	validation-rmse:4.30302
# [35]	validation-rmse:4.30332
# [36]	validation-rmse:4.30352
# [37]	validation-rmse:4.30368
# [38]	validation-rmse:4.30382
# [39]	validation-rmse:4.30395
# [40]	validation-rmse:4.30409
# [41]	validation-rmse:4.30421
# [42]	validation-rmse:4.30432
# [43]	validation-rmse:4.30441
# [44]	validation-rmse:4.30451
# [45]	validation-rmse:4.30457
# [46]	validation-rmse:4.30464
# [47]	validation-rmse:4.30469
# [48]	validation-rmse:4.30476
# [49]	validation-rmse:4.30481
# [50]	validation-rmse:4.30486
# [51]	validation-rmse:4.30490
# [52]	validation-rmse:4.30494
# [53]	validation-rmse:4.30497
# [54]	validation-rmse:4.30501
# [55]	validation-rmse:4.30504
# [56]	validation-rmse:4.30507
# [57]	validation-rmse:4.30509
# [0]	validation-rmse:7.66956
# [1]	validation-rmse:6.10454
# [2]	validation-rmse:5.19363
# [3]	validation-rmse:4.66532
# [4]	validation-rmse:4.38307
# [5]	validation-rmse:4.25844
# [6]	validation-rmse:4.20587
# [7]	validation-rmse:4.18807
# [8]	validation-rmse:4.18596
# [9]	validation-rmse:4.19376
# [10]	validation-rmse:4.19831
# [11]	validation-rmse:4.20795
# [12]	validation-rmse:4.21527
# [13]	validation-rmse:4.22352
# [14]	validation-rmse:4.23082
# [15]	validation-rmse:4.23814
# [16]	validation-rmse:4.24454
# [17]	validation-rmse:4.24892
# [18]	validation-rmse:4.25223
# [19]	validation-rmse:4.25584
# [20]	validation-rmse:4.25857
# [21]	validation-rmse:4.26151
# [22]	validation-rmse:4.26278
# [23]	validation-rmse:4.26480
# [24]	validation-rmse:4.26640
# [25]	validation-rmse:4.26762
# [26]	validation-rmse:4.26926
# [27]	validation-rmse:4.27027
# [28]	validation-rmse:4.27118
# [29]	validation-rmse:4.27177
# [30]	validation-rmse:4.27234
# [31]	validation-rmse:4.27285
# [32]	validation-rmse:4.27331
# [33]	validation-rmse:4.27391
# [34]	validation-rmse:4.27423
# [35]	validation-rmse:4.27456
# [36]	validation-rmse:4.27496
# [37]	validation-rmse:4.27528
# [38]	validation-rmse:4.27561
# [39]	validation-rmse:4.27601
# [40]	validation-rmse:4.27639
# [41]	validation-rmse:4.27664
# [42]	validation-rmse:4.27694
# [43]	validation-rmse:4.27718
# [44]	validation-rmse:4.27742
# [45]	validation-rmse:4.27753
# [46]	validation-rmse:4.27783
# [47]	validation-rmse:4.27799
# [48]	validation-rmse:4.27819
# [49]	validation-rmse:4.27840
# [50]	validation-rmse:4.27859
# [51]	validation-rmse:4.27883
# [52]	validation-rmse:4.27913
# [53]	validation-rmse:4.27933
# [54]	validation-rmse:4.27955
# [55]	validation-rmse:4.27965
# [56]	validation-rmse:4.27976
# [57]	validation-rmse:4.27991
# [0]	validation-rmse:7.66939
# [1]	validation-rmse:6.10808
# [2]	validation-rmse:5.19904
# [3]	validation-rmse:4.67502
# [4]	validation-rmse:4.39413
# [5]	validation-rmse:4.25095
# [6]	validation-rmse:4.19288
# [7]	validation-rmse:4.16925
# [8]	validation-rmse:4.16310
# [9]	validation-rmse:4.16200
# [10]	validation-rmse:4.16338
# [11]	validation-rmse:4.17159
# [12]	validation-rmse:4.18263
# [13]	validation-rmse:4.19029
# [14]	validation-rmse:4.19638
# [15]	validation-rmse:4.20390
# [16]	validation-rmse:4.21117
# [17]	validation-rmse:4.21572
# [18]	validation-rmse:4.22057
# [19]	validation-rmse:4.22369
# [20]	validation-rmse:4.22731
# [21]	validation-rmse:4.22968
# [22]	validation-rmse:4.23198
# [23]	validation-rmse:4.23333
# [24]	validation-rmse:4.23500
# [25]	validation-rmse:4.23606
# [26]	validation-rmse:4.23705
# [27]	validation-rmse:4.23794
# [28]	validation-rmse:4.23894
# [29]	validation-rmse:4.23972
# [30]	validation-rmse:4.24069
# [31]	validation-rmse:4.24174
# [32]	validation-rmse:4.24206
# [33]	validation-rmse:4.24237
# [34]	validation-rmse:4.24260
# [35]	validation-rmse:4.24279
# [36]	validation-rmse:4.24330
# [37]	validation-rmse:4.24350
# [38]	validation-rmse:4.24383
# [39]	validation-rmse:4.24420
# [40]	validation-rmse:4.24454
# [41]	validation-rmse:4.24482
# [42]	validation-rmse:4.24491
# [43]	validation-rmse:4.24504
# [44]	validation-rmse:4.24548
# [45]	validation-rmse:4.24574
# [46]	validation-rmse:4.24620
# [47]	validation-rmse:4.24676
# [48]	validation-rmse:4.24710
# [49]	validation-rmse:4.24738
# [50]	validation-rmse:4.24755
# [51]	validation-rmse:4.24777
# [52]	validation-rmse:4.24803
# [53]	validation-rmse:4.24821
# [54]	validation-rmse:4.24851
# [55]	validation-rmse:4.24868
# [56]	validation-rmse:4.24888
# [57]	validation-rmse:4.24907
# [58]	validation-rmse:4.24935
# [0]	validation-rmse:7.66498
# [1]	validation-rmse:6.07790
# [2]	validation-rmse:5.12520
# [3]	validation-rmse:4.56116
# [4]	validation-rmse:4.26266
# [5]	validation-rmse:4.11287
# [6]	validation-rmse:4.03078
# [7]	validation-rmse:3.99471
# [8]	validation-rmse:3.96957
# [9]	validation-rmse:3.95956
# [10]	validation-rmse:3.94958
# [11]	validation-rmse:3.94305
# [12]	validation-rmse:3.94767
# [13]	validation-rmse:3.94863
# [14]	validation-rmse:3.94674
# [15]	validation-rmse:3.94695
# [16]	validation-rmse:3.94181
# [17]	validation-rmse:3.94426
# [18]	validation-rmse:3.94814
# [19]	validation-rmse:3.95420
# [20]	validation-rmse:3.95601
# [21]	validation-rmse:3.95147
# [22]	validation-rmse:3.95661
# [23]	validation-rmse:3.95631
# [24]	validation-rmse:3.95707
# [25]	validation-rmse:3.96015
# [26]	validation-rmse:3.96129
# [27]	validation-rmse:3.96136
# [28]	validation-rmse:3.96077
# [29]	validation-rmse:3.96418
# [30]	validation-rmse:3.96523
# [31]	validation-rmse:3.96692
# [32]	validation-rmse:3.96908
# [33]	validation-rmse:3.97055
# [34]	validation-rmse:3.97331
# [35]	validation-rmse:3.97393
# [36]	validation-rmse:3.97403
# [37]	validation-rmse:3.97392
# [38]	validation-rmse:3.97307
# [39]	validation-rmse:3.97561
# [40]	validation-rmse:3.97473
# [41]	validation-rmse:3.97584
# [42]	validation-rmse:3.97657
# [43]	validation-rmse:3.98211
# [44]	validation-rmse:3.98162
# [45]	validation-rmse:3.98268
# [46]	validation-rmse:3.98471
# [47]	validation-rmse:3.98701
# [48]	validation-rmse:3.98831
# [49]	validation-rmse:3.99113
# [50]	validation-rmse:3.99224
# [51]	validation-rmse:3.99555
# [52]	validation-rmse:3.99743
# [53]	validation-rmse:3.99689
# [54]	validation-rmse:3.99925
# [55]	validation-rmse:3.99980
# [56]	validation-rmse:4.00408
# [57]	validation-rmse:4.00441
# [58]	validation-rmse:4.00352
# [59]	validation-rmse:4.00647
# [60]	validation-rmse:4.00850
# [61]	validation-rmse:4.01072
# [62]	validation-rmse:4.01141
# [63]	validation-rmse:4.01149
# [64]	validation-rmse:4.01197
# [65]	validation-rmse:4.01306
# [66]	validation-rmse:4.01400
# [0]	validation-rmse:7.66930
# [1]	validation-rmse:6.10444
# [2]	validation-rmse:5.19518
# [3]	validation-rmse:4.67301
# [4]	validation-rmse:4.38881
# [5]	validation-rmse:4.25996
# [6]	validation-rmse:4.19908
# [7]	validation-rmse:4.18270
# [8]	validation-rmse:4.17966
# [9]	validation-rmse:4.18537
# [10]	validation-rmse:4.19613
# [11]	validation-rmse:4.20442
# [12]	validation-rmse:4.21670
# [13]	validation-rmse:4.22092
# [14]	validation-rmse:4.22858
# [15]	validation-rmse:4.23403
# [16]	validation-rmse:4.23963
# [17]	validation-rmse:4.24435
# [18]	validation-rmse:4.24977
# [19]	validation-rmse:4.25256
# [20]	validation-rmse:4.25550
# [21]	validation-rmse:4.25835
# [22]	validation-rmse:4.26053
# [23]	validation-rmse:4.26257
# [24]	validation-rmse:4.26431
# [25]	validation-rmse:4.26532
# [26]	validation-rmse:4.26620
# [27]	validation-rmse:4.26723
# [28]	validation-rmse:4.26812
# [29]	validation-rmse:4.26888
# [30]	validation-rmse:4.26939
# [31]	validation-rmse:4.26984
# [32]	validation-rmse:4.27032
# [33]	validation-rmse:4.27062
# [34]	validation-rmse:4.27093
# [35]	validation-rmse:4.27126
# [36]	validation-rmse:4.27159
# [37]	validation-rmse:4.27183
# [38]	validation-rmse:4.27208
# [39]	validation-rmse:4.27227
# [40]	validation-rmse:4.27252
# [41]	validation-rmse:4.27267
# [42]	validation-rmse:4.27288
# [43]	validation-rmse:4.27301
# [44]	validation-rmse:4.27315
# [45]	validation-rmse:4.27331
# [46]	validation-rmse:4.27344
# [47]	validation-rmse:4.27356
# [48]	validation-rmse:4.27365
# [49]	validation-rmse:4.27373
# [50]	validation-rmse:4.27380
# [51]	validation-rmse:4.27385
# [52]	validation-rmse:4.27390
# [53]	validation-rmse:4.27395
# [54]	validation-rmse:4.27399
# [55]	validation-rmse:4.27404
# [56]	validation-rmse:4.27411
# [57]	validation-rmse:4.27417
# [58]	validation-rmse:4.27421
# [0]	validation-rmse:7.75244
# [1]	validation-rmse:6.23778
# [2]	validation-rmse:5.31216
# [3]	validation-rmse:4.78725
# [4]	validation-rmse:4.47212
# [5]	validation-rmse:4.30803
# [6]	validation-rmse:4.17418
# [7]	validation-rmse:4.10853
# [8]	validation-rmse:4.05974
# [9]	validation-rmse:4.03779
# [10]	validation-rmse:4.00223
# [11]	validation-rmse:3.97548
# [12]	validation-rmse:3.96546
# [13]	validation-rmse:3.93574
# [14]	validation-rmse:3.92883
# [15]	validation-rmse:3.92641
# [16]	validation-rmse:3.92591
# [17]	validation-rmse:3.91226
# [18]	validation-rmse:3.91154
# [19]	validation-rmse:3.90776
# [20]	validation-rmse:3.90495
# [21]	validation-rmse:3.89445
# [22]	validation-rmse:3.89311
# [23]	validation-rmse:3.88631
# [24]	validation-rmse:3.87447
# [25]	validation-rmse:3.87542
# [26]	validation-rmse:3.87173
# [27]	validation-rmse:3.86803
# [28]	validation-rmse:3.85953
# [29]	validation-rmse:3.86070
# [30]	validation-rmse:3.86111
# [31]	validation-rmse:3.86084
# [32]	validation-rmse:3.85673
# [33]	validation-rmse:3.85353
# [34]	validation-rmse:3.85357
# [35]	validation-rmse:3.85309
# [36]	validation-rmse:3.84484
# [37]	validation-rmse:3.84778
# [38]	validation-rmse:3.84516
# [39]	validation-rmse:3.84135
# [40]	validation-rmse:3.83890
# [41]	validation-rmse:3.83964
# [42]	validation-rmse:3.84093
# [43]	validation-rmse:3.84137
# [44]	validation-rmse:3.83021
# [45]	validation-rmse:3.83400
# [46]	validation-rmse:3.83403
# [47]	validation-rmse:3.82845
# [48]	validation-rmse:3.82677
# [49]	validation-rmse:3.82735
# [50]	validation-rmse:3.82539
# [51]	validation-rmse:3.82620
# [52]	validation-rmse:3.82702
# [53]	validation-rmse:3.82590
# [54]	validation-rmse:3.82581
# [55]	validation-rmse:3.82555
# [56]	validation-rmse:3.82787
# [57]	validation-rmse:3.82786
# [58]	validation-rmse:3.82662
# [59]	validation-rmse:3.82853
# [60]	validation-rmse:3.82981
# [61]	validation-rmse:3.82982
# [62]	validation-rmse:3.82750
# [63]	validation-rmse:3.83055
# [64]	validation-rmse:3.82936
# [65]	validation-rmse:3.82754
# [66]	validation-rmse:3.82809
# [67]	validation-rmse:3.82302
# [68]	validation-rmse:3.82352
# [69]	validation-rmse:3.82112
# [70]	validation-rmse:3.81879
# [71]	validation-rmse:3.81894
# [72]	validation-rmse:3.81873
# [73]	validation-rmse:3.82042
# [74]	validation-rmse:3.82209
# [75]	validation-rmse:3.82301
# [76]	validation-rmse:3.82302
# [77]	validation-rmse:3.82235
# [78]	validation-rmse:3.81726
# [79]	validation-rmse:3.81667
# [80]	validation-rmse:3.81828
# [81]	validation-rmse:3.82049
# [82]	validation-rmse:3.82138
# [83]	validation-rmse:3.82271
# [84]	validation-rmse:3.82512
# [85]	validation-rmse:3.82429
# [86]	validation-rmse:3.82275
# [87]	validation-rmse:3.82244
# [88]	validation-rmse:3.81958
# [89]	validation-rmse:3.81874
# [90]	validation-rmse:3.81802
# [91]	validation-rmse:3.81888
# [92]	validation-rmse:3.81986
# [93]	validation-rmse:3.81842
# [94]	validation-rmse:3.82280
# [95]	validation-rmse:3.82317
# [96]	validation-rmse:3.82245
# [97]	validation-rmse:3.82363
# [98]	validation-rmse:3.82430
# [99]	validation-rmse:3.82520
# [0]	validation-rmse:7.66969
# [1]	validation-rmse:6.10534
# [2]	validation-rmse:5.19514
# [3]	validation-rmse:4.67285
# [4]	validation-rmse:4.39091
# [5]	validation-rmse:4.25864
# [6]	validation-rmse:4.19256
# [7]	validation-rmse:4.16770
# [8]	validation-rmse:4.16366
# [9]	validation-rmse:4.16768
# [10]	validation-rmse:4.17654
# [11]	validation-rmse:4.18753
# [12]	validation-rmse:4.20048
# [13]	validation-rmse:4.21073
# [14]	validation-rmse:4.21881
# [15]	validation-rmse:4.22647
# [16]	validation-rmse:4.23109
# [17]	validation-rmse:4.23497
# [18]	validation-rmse:4.23986
# [19]	validation-rmse:4.24224
# [20]	validation-rmse:4.24546
# [21]	validation-rmse:4.24747
# [22]	validation-rmse:4.24944
# [23]	validation-rmse:4.25068
# [24]	validation-rmse:4.25189
# [25]	validation-rmse:4.25292
# [26]	validation-rmse:4.25403
# [27]	validation-rmse:4.25502
# [28]	validation-rmse:4.25594
# [29]	validation-rmse:4.25694
# [30]	validation-rmse:4.25792
# [31]	validation-rmse:4.25845
# [32]	validation-rmse:4.25915
# [33]	validation-rmse:4.25982
# [34]	validation-rmse:4.26008
# [35]	validation-rmse:4.26044
# [36]	validation-rmse:4.26078
# [37]	validation-rmse:4.26120
# [38]	validation-rmse:4.26167
# [39]	validation-rmse:4.26188
# [40]	validation-rmse:4.26210
# [41]	validation-rmse:4.26233
# [42]	validation-rmse:4.26271
# [43]	validation-rmse:4.26285
# [44]	validation-rmse:4.26313
# [45]	validation-rmse:4.26335
# [46]	validation-rmse:4.26360
# [47]	validation-rmse:4.26375
# [48]	validation-rmse:4.26394
# [49]	validation-rmse:4.26409
# [50]	validation-rmse:4.26426
# [51]	validation-rmse:4.26440
# [52]	validation-rmse:4.26448
# [53]	validation-rmse:4.26457
# [54]	validation-rmse:4.26466
# [55]	validation-rmse:4.26478
# [56]	validation-rmse:4.26489
# [57]	validation-rmse:4.26499
# [0]	validation-rmse:7.90603
# [1]	validation-rmse:6.46324
# [2]	validation-rmse:5.61020
# [3]	validation-rmse:5.11010
# [4]	validation-rmse:4.80299
# [5]	validation-rmse:4.64741
# [6]	validation-rmse:4.55346
# [7]	validation-rmse:4.49126
# [8]	validation-rmse:4.40927
# [9]	validation-rmse:4.37035
# [10]	validation-rmse:4.33722
# [11]	validation-rmse:4.30028
# [12]	validation-rmse:4.27388
# [13]	validation-rmse:4.23775
# [14]	validation-rmse:4.22179
# [15]	validation-rmse:4.20075
# [16]	validation-rmse:4.19041
# [17]	validation-rmse:4.17558
# [18]	validation-rmse:4.17069
# [19]	validation-rmse:4.15192
# [20]	validation-rmse:4.14214
# [21]	validation-rmse:4.12355
# [22]	validation-rmse:4.11940
# [23]	validation-rmse:4.11760
# [24]	validation-rmse:4.10336
# [25]	validation-rmse:4.09977
# [26]	validation-rmse:4.10027
# [27]	validation-rmse:4.09849
# [28]	validation-rmse:4.09016
# [29]	validation-rmse:4.08945
# [30]	validation-rmse:4.08605
# [31]	validation-rmse:4.08594
# [32]	validation-rmse:4.08645
# [33]	validation-rmse:4.08544
# [34]	validation-rmse:4.06473
# [35]	validation-rmse:4.05755
# [36]	validation-rmse:4.05175
# [37]	validation-rmse:4.04994
# [38]	validation-rmse:4.03886
# [39]	validation-rmse:4.03725
# [40]	validation-rmse:4.02645
# [41]	validation-rmse:4.01048
# [42]	validation-rmse:4.01045
# [43]	validation-rmse:3.99778
# [44]	validation-rmse:3.99511
# [45]	validation-rmse:3.99076
# [46]	validation-rmse:3.98955
# [47]	validation-rmse:3.99008
# [48]	validation-rmse:3.98897
# [49]	validation-rmse:3.98932
# [50]	validation-rmse:3.98741
# [51]	validation-rmse:3.98797
# [52]	validation-rmse:3.98735
# [53]	validation-rmse:3.96916
# [54]	validation-rmse:3.96616
# [55]	validation-rmse:3.96760
# [56]	validation-rmse:3.96647
# [57]	validation-rmse:3.96495
# [58]	validation-rmse:3.96519
# [59]	validation-rmse:3.96373
# [60]	validation-rmse:3.96337
# [61]	validation-rmse:3.95721
# [62]	validation-rmse:3.95561
# [63]	validation-rmse:3.95720
# [64]	validation-rmse:3.95661
# [65]	validation-rmse:3.95469
# [66]	validation-rmse:3.95584
# [67]	validation-rmse:3.95482
# [68]	validation-rmse:3.95441
# [69]	validation-rmse:3.95549
# [70]	validation-rmse:3.95541
# [71]	validation-rmse:3.95394
# [72]	validation-rmse:3.95140
# [73]	validation-rmse:3.94757
# [74]	validation-rmse:3.94577
# [75]	validation-rmse:3.93494
# [76]	validation-rmse:3.92969
# [77]	validation-rmse:3.92427
# [78]	validation-rmse:3.92468
# [79]	validation-rmse:3.92449
# [80]	validation-rmse:3.92419
# [81]	validation-rmse:3.92207
# [82]	validation-rmse:3.92106
# [83]	validation-rmse:3.91829
# [84]	validation-rmse:3.91547
# [85]	validation-rmse:3.91221
# [86]	validation-rmse:3.90914
# [87]	validation-rmse:3.90539
# [88]	validation-rmse:3.90442
# [89]	validation-rmse:3.90555
# [90]	validation-rmse:3.90478
# [91]	validation-rmse:3.90201
# [92]	validation-rmse:3.89336
# [93]	validation-rmse:3.89332
# [94]	validation-rmse:3.89234
# [95]	validation-rmse:3.89203
# [96]	validation-rmse:3.88671
# [97]	validation-rmse:3.88907
# [98]	validation-rmse:3.88945
# [99]	validation-rmse:3.88618
# [0]	validation-rmse:7.66960
# [1]	validation-rmse:6.10853
# [2]	validation-rmse:5.19937
# [3]	validation-rmse:4.67458
# [4]	validation-rmse:4.38884
# [5]	validation-rmse:4.25580
# [6]	validation-rmse:4.19864
# [7]	validation-rmse:4.17480
# [8]	validation-rmse:4.17382
# [9]	validation-rmse:4.18164
# [10]	validation-rmse:4.18700
# [11]	validation-rmse:4.19899
# [12]	validation-rmse:4.21102
# [13]	validation-rmse:4.22247
# [14]	validation-rmse:4.23296
# [15]	validation-rmse:4.24279
# [16]	validation-rmse:4.24905
# [17]	validation-rmse:4.25591
# [18]	validation-rmse:4.26087
# [19]	validation-rmse:4.26394
# [20]	validation-rmse:4.26630
# [21]	validation-rmse:4.26847
# [22]	validation-rmse:4.27083
# [23]	validation-rmse:4.27248
# [24]	validation-rmse:4.27432
# [25]	validation-rmse:4.27575
# [26]	validation-rmse:4.27687
# [27]	validation-rmse:4.27783
# [28]	validation-rmse:4.27880
# [29]	validation-rmse:4.27963
# [30]	validation-rmse:4.28029
# [31]	validation-rmse:4.28079
# [32]	validation-rmse:4.28125
# [33]	validation-rmse:4.28161
# [34]	validation-rmse:4.28189
# [35]	validation-rmse:4.28212
# [36]	validation-rmse:4.28233
# [37]	validation-rmse:4.28250
# [38]	validation-rmse:4.28267
# [39]	validation-rmse:4.28276
# [40]	validation-rmse:4.28286
# [41]	validation-rmse:4.28295
# [42]	validation-rmse:4.28302
# [43]	validation-rmse:4.28307
# [44]	validation-rmse:4.28313
# [45]	validation-rmse:4.28318
# [46]	validation-rmse:4.28323
# [47]	validation-rmse:4.28327
# [48]	validation-rmse:4.28328
# [49]	validation-rmse:4.28331
# [50]	validation-rmse:4.28333
# [51]	validation-rmse:4.28334
# [52]	validation-rmse:4.28336
# [53]	validation-rmse:4.28337
# [54]	validation-rmse:4.28339
# [55]	validation-rmse:4.28339
# [56]	validation-rmse:4.28340
# [57]	validation-rmse:4.28341
# [58]	validation-rmse:4.28342
# [0]	validation-rmse:7.66958
# [1]	validation-rmse:6.10446
# [2]	validation-rmse:5.19169
# [3]	validation-rmse:4.66002
# [4]	validation-rmse:4.37674
# [5]	validation-rmse:4.24046
# [6]	validation-rmse:4.19309
# [7]	validation-rmse:4.16497
# [8]	validation-rmse:4.15475
# [9]	validation-rmse:4.15866
# [10]	validation-rmse:4.16375
# [11]	validation-rmse:4.16869
# [12]	validation-rmse:4.17922
# [13]	validation-rmse:4.19013
# [14]	validation-rmse:4.19876
# [15]	validation-rmse:4.20691
# [16]	validation-rmse:4.21109
# [17]	validation-rmse:4.21495
# [18]	validation-rmse:4.21931
# [19]	validation-rmse:4.22341
# [20]	validation-rmse:4.22587
# [21]	validation-rmse:4.22814
# [22]	validation-rmse:4.23029
# [23]	validation-rmse:4.23197
# [24]	validation-rmse:4.23338
# [25]	validation-rmse:4.23472
# [26]	validation-rmse:4.23565
# [27]	validation-rmse:4.23687
# [28]	validation-rmse:4.23746
# [29]	validation-rmse:4.23806
# [30]	validation-rmse:4.23853
# [31]	validation-rmse:4.23906
# [32]	validation-rmse:4.23942
# [33]	validation-rmse:4.24003
# [34]	validation-rmse:4.24048
# [35]	validation-rmse:4.24096
# [36]	validation-rmse:4.24127
# [37]	validation-rmse:4.24152
# [38]	validation-rmse:4.24179
# [39]	validation-rmse:4.24210
# [40]	validation-rmse:4.24239
# [41]	validation-rmse:4.24264
# [42]	validation-rmse:4.24280
# [43]	validation-rmse:4.24301
# [44]	validation-rmse:4.24326
# [45]	validation-rmse:4.24344
# [46]	validation-rmse:4.24363
# [47]	validation-rmse:4.24377
# [48]	validation-rmse:4.24388
# [49]	validation-rmse:4.24400
# [50]	validation-rmse:4.24414
# [51]	validation-rmse:4.24427
# [52]	validation-rmse:4.24438
# [53]	validation-rmse:4.24447
# [54]	validation-rmse:4.24459
# [55]	validation-rmse:4.24468
# [56]	validation-rmse:4.24479
# [57]	validation-rmse:4.24484
# [58]	validation-rmse:4.24493
# 100%|████████████████████| 10/10 [00:25<00:00,  2.60s/trial, best loss: 14.63216015221906]

# %%
best_params = {
    "max_depth":6,
    "reg_alpha":0.07465666333107646
}

mlflow.xgboost.autolog()

booster = xgb.train(
            params=best_params,
            dtrain=train,
            evals=[(validation, "validation")],
            num_boost_round=100,
            early_stopping_rounds=50  
        )
# Out:
# 2024/07/15 20:15:11 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of xgboost. If you encounter errors during autologging, try upgrading / downgrading xgboost to a supported version, or try upgrading MLflow.
# 2024/07/15 20:15:11 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '156bf8a4b1474266bad2244e85f60161', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [0]	validation-rmse:7.75239
# [1]	validation-rmse:6.23769
# [2]	validation-rmse:5.31209
# [3]	validation-rmse:4.78718
# [4]	validation-rmse:4.47202
# [5]	validation-rmse:4.30772
# [6]	validation-rmse:4.17385
# [7]	validation-rmse:4.10846
# [8]	validation-rmse:4.05886
# [9]	validation-rmse:4.03666
# [10]	validation-rmse:4.00153
# [11]	validation-rmse:3.97287
# [12]	validation-rmse:3.96543
# [13]	validation-rmse:3.94011
# [14]	validation-rmse:3.93313
# [15]	validation-rmse:3.92033
# [16]	validation-rmse:3.92146
# [17]	validation-rmse:3.92034
# [18]	validation-rmse:3.90524
# [19]	validation-rmse:3.90141
# [20]	validation-rmse:3.89943
# [21]	validation-rmse:3.89284
# [22]	validation-rmse:3.89436
# [23]	validation-rmse:3.88783
# [24]	validation-rmse:3.88382
# [25]	validation-rmse:3.88711
# [26]	validation-rmse:3.88973
# [27]	validation-rmse:3.89018
# [28]	validation-rmse:3.89055
# [29]	validation-rmse:3.89335
# [30]	validation-rmse:3.87959
# [31]	validation-rmse:3.87042
# [32]	validation-rmse:3.86457
# [33]	validation-rmse:3.86259
# [34]	validation-rmse:3.86486
# [35]	validation-rmse:3.86323
# [36]	validation-rmse:3.86285
# [37]	validation-rmse:3.86490
# [38]	validation-rmse:3.86369
# [39]	validation-rmse:3.86457
# [40]	validation-rmse:3.86392
# [41]	validation-rmse:3.86058
# [42]	validation-rmse:3.86073
# [43]	validation-rmse:3.86186
# [44]	validation-rmse:3.85063
# [45]	validation-rmse:3.84970
# [46]	validation-rmse:3.85139
# [47]	validation-rmse:3.85360
# [48]	validation-rmse:3.85332
# [49]	validation-rmse:3.85311
# [50]	validation-rmse:3.85534
# [51]	validation-rmse:3.85031
# [52]	validation-rmse:3.85100
# [53]	validation-rmse:3.84648
# [54]	validation-rmse:3.84614
# [55]	validation-rmse:3.83917
# [56]	validation-rmse:3.84034
# [57]	validation-rmse:3.83974
# [58]	validation-rmse:3.84198
# [59]	validation-rmse:3.84382
# [60]	validation-rmse:3.84505
# [61]	validation-rmse:3.84367
# [62]	validation-rmse:3.84065
# [63]	validation-rmse:3.84398
# [64]	validation-rmse:3.84336
# [65]	validation-rmse:3.84264
# [66]	validation-rmse:3.84203
# [67]	validation-rmse:3.84318
# [68]	validation-rmse:3.84261
# [69]	validation-rmse:3.84573
# [70]	validation-rmse:3.84550
# [71]	validation-rmse:3.84622
# [72]	validation-rmse:3.84681
# [73]	validation-rmse:3.84613
# [74]	validation-rmse:3.84520
# [75]	validation-rmse:3.84591
# [76]	validation-rmse:3.84348
# [77]	validation-rmse:3.84731
# [78]	validation-rmse:3.84943
# [79]	validation-rmse:3.85042
# [80]	validation-rmse:3.85024
# [81]	validation-rmse:3.85396
# [82]	validation-rmse:3.85738
# [83]	validation-rmse:3.86044
# [84]	validation-rmse:3.85800
# [85]	validation-rmse:3.85864
# [86]	validation-rmse:3.86039
# [87]	validation-rmse:3.86059
# [88]	validation-rmse:3.86537
# [89]	validation-rmse:3.86760
# [90]	validation-rmse:3.86922
# [91]	validation-rmse:3.87080
# [92]	validation-rmse:3.87277
# [93]	validation-rmse:3.87269
# [94]	validation-rmse:3.87331
# [95]	validation-rmse:3.87420
# [96]	validation-rmse:3.88056
# [97]	validation-rmse:3.87893
# [98]	validation-rmse:3.87683
# [99]	validation-rmse:3.87690
# 2024/07/15 20:15:12 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# 2024/07/15 20:15:12 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [20:15:12] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
# 2024/07/15 20:15:13 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2024/07/15 20:15:13 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils."

# %% [markdown]
# ## Load Model

# %%
logged_model_id = 'runs:/156bf8a4b1474266bad2244e85f60161/model'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model_id)

# %%
type(loaded_model)
# Out:
# mlflow.pyfunc.PyFuncModel

# %%
y_val_pred_load_model = loaded_model.predict(X_val)

# %%
rmse = mean_squared_error(y_val, y_val_pred_load_model, squared=False)
rmse
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 3.8768980813085387

# %% [markdown]
# ## Mlflow Client

# %%
from mlflow.tracking import MlflowClient
from mlflow.entities import ViewType

# %%
MLFLOW_URI = "sqlite:///mlflow.db"

# %%
client = MlflowClient(MLFLOW_URI)

# %%
client.create_experiment(name = "New experimnet created from the python API")
# Out:
# '3'

# %%
client.get_experiment_by_name("green_taxi")
# Out:
# <Experiment: artifact_location='/Users/emelidral/Dev/m13_2024/experiments/mlruns/1', creation_time=1721062613079, experiment_id='1', last_update_time=1721062613079, lifecycle_stage='active', name='green_taxi', tags={}>

# %%
runs = client.search_runs(
    experiment_ids='1',
    max_results=10
)

# %%
len(runs)
# Out:
# 10

# %%
for run in runs:
    print(run)
# Out:
# <Run: data=<RunData: metrics={'rmse': 34.90734333193174}, params={'alpha': '0.05',
#  'model_name': 'Lasso',
#  'train_data': 'data/green_tripdata_2024-03.parquet'}, tags={'mlflow.runName': 'angry-hare-180',
#  'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'emelidral',
#  'workspace': 'inclass'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/m13_2024/experiments/mlruns/1/1e8c2ca3d01f4a0592a3589818e6504e/artifacts', end_time=1721133662165, experiment_id='1', lifecycle_stage='active', run_id='1e8c2ca3d01f4a0592a3589818e6504e', run_name='angry-hare-180', run_uuid='1e8c2ca3d01f4a0592a3589818e6504e', start_time=1721133662088, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[]>>
# <Run: data=<RunData: metrics={'best_iteration': 55.0,
#  'stopped_iteration': 99.0,
#  'validation-rmse': 3.8391727821808983}, params={'custom_metric': 'None',
#  'early_stopping_rounds': '50',
#  'max_depth': '6',
#  'maximize': 'None',
#  'num_boost_round': '100',
#  'reg_alpha': '0.07465666333107646',
#  'verbose_eval': 'True'}, tags={'mlflow.autologging': 'xgboost',
#  'mlflow.log-model.history': '[{"run_id": "156bf8a4b1474266bad2244e85f60161", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2024-07-15 18:15:12.271434", "flavors": '
#                              '{"python_function": {"loader_module": '
#                              '"mlflow.xgboost", "python_version": "3.11.9", '
#                              '"data": "model.xgb", "env": {"conda": '
#                              '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                              '"xgboost": {"xgb_version": "2.1.0", "data": '
#                              '"model.xgb", "model_class": '
#                              '"xgboost.core.Booster", "model_format": "xgb", '
#                              '"code": null}}, "model_uuid": '
#                              '"e67185866ba647a8ab2051ae2b8a3c8f", '
#                              '"mlflow_version": "2.14.3", "model_size_bytes": '
#                              '398095}]',
#  'mlflow.runName': 'stately-mink-217',
#  'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/m13_2024/experiments/mlruns/1/156bf8a4b1474266bad2244e85f60161/artifacts', end_time=1721067313319, experiment_id='1', lifecycle_stage='active', run_id='156bf8a4b1474266bad2244e85f60161', run_name='stately-mink-217', run_uuid='156bf8a4b1474266bad2244e85f60161', start_time=1721067311741, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='d4931da7', name='dataset', profile=('{"features_shape": [55463, 5], "features_size": 277315, "features_nbytes": '
#  '1109260}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#  '"/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='train'>]>,
#  <DatasetInput: dataset=<Dataset: digest='5bfd52e6', name='validation', profile=('{"features_shape": [54380, 5], "features_size": 271900, "features_nbytes": '
#  '1087600}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#  '"/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>
# <Run: data=<RunData: metrics={'validation-rmse': 4.0366592713094285}, params={}, tags={'mlflow.autologging': 'xgboost',
#  'mlflow.log-model.history': '[{"run_id": "ddf21f2b704447a09222f1288179c56e", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2024-07-15 18:14:08.673947", "flavors": '
#                              '{"python_function": {"loader_module": '
#                              '"mlflow.xgboost", "python_version": "3.11.9", '
#                              '"data": "model.xgb", "env": {"conda": '
#                              '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                              '"xgboost": {"xgb_version": "2.1.0", "data": '
#                              '"model.xgb", "model_class": '
#                              '"xgboost.core.Booster", "model_format": "xgb", '
#                              '"code": null}}, "model_uuid": '
#                              '"e308c5996aad4f1aa1f9c06845241685", '
#                              '"mlflow_version": "2.14.3", "model_size_bytes": '
#                              '49564}]',
#  'mlflow.runName': 'peaceful-newt-942',
#  'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/m13_2024/experiments/mlruns/1/ddf21f2b704447a09222f1288179c56e/artifacts', end_time=1721067249726, experiment_id='1', lifecycle_stage='active', run_id='ddf21f2b704447a09222f1288179c56e', run_name='peaceful-newt-942', run_uuid='ddf21f2b704447a09222f1288179c56e', start_time=1721067248534, status='FAILED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='d4931da7', name='dataset', profile=('{"features_shape": [55463, 5], "features_size": 277315, "features_nbytes": '
#  '1109260}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#  '"/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='train'>]>,
#  <DatasetInput: dataset=<Dataset: digest='5bfd52e6', name='validation', profile=('{"features_shape": [54380, 5], "features_size": 271900, "features_nbytes": '
#  '1087600}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#  '"/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>
# <Run: data=<RunData: metrics={'best_iteration': 55.0,
#  'stopped_iteration': 99.0,
#  'validation-rmse': 3.8391727821808983}, params={}, tags={'mlflow.autologging': 'xgboost',
#  'mlflow.log-model.history': '[{"run_id": "eb5dce3d3d3b4d388ce1ec2892d83611", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2024-07-15 18:13:40.331887", "flavors": '
#                              '{"python_function": {"loader_module": '
#                              '"mlflow.xgboost", "python_version": "3.11.9", '
#                              '"data": "model.xgb", "env": {"conda": '
#                              '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                              '"xgboost": {"xgb_version": "2.1.0", "data": '
#                              '"model.xgb", "model_class": '
#                              '"xgboost.core.Booster", "model_format": "xgb", '
#                              '"code": null}}, "model_uuid": '
#                              '"f5acaa68450640e598a5a42b54704d8c", '
#                              '"mlflow_version": "2.14.3", "model_size_bytes": '
#                              '398095}]',
#  'mlflow.runName': 'stylish-donkey-799',
#  'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/m13_2024/experiments/mlruns/1/eb5dce3d3d3b4d388ce1ec2892d83611/artifacts', end_time=1721067221602, experiment_id='1', lifecycle_stage='active', run_id='eb5dce3d3d3b4d388ce1ec2892d83611', run_name='stylish-donkey-799', run_uuid='eb5dce3d3d3b4d388ce1ec2892d83611', start_time=1721067219847, status='FAILED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='d4931da7', name='dataset', profile=('{"features_shape": [55463, 5], "features_size": 277315, "features_nbytes": '
#  '1109260}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#  '"/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='train'>]>,
#  <DatasetInput: dataset=<Dataset: digest='5bfd52e6', name='validation', profile=('{"features_shape": [54380, 5], "features_size": 271900, "features_nbytes": '
#  '1087600}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#  '"/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>
# <Run: data=<RunData: metrics={'best_iteration': 55.0,
#  'stopped_iteration': 99.0,
#  'validation-rmse': 3.8391727821808983}, params={}, tags={'mlflow.autologging': 'xgboost',
#  'mlflow.log-model.history': '[{"run_id": "c0568075b89646b692652e001a39a74a", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2024-07-15 18:12:46.697980", "flavors": '
#                              '{"python_function": {"loader_module": '
#                              '"mlflow.xgboost", "python_version": "3.11.9", '
#                              '"data": "model.xgb", "env": {"conda": '
#                              '"conda.yaml", "virtualenv": "python_env.yaml"}}, '
#                              '"xgboost": {"xgb_version": "2.1.0", "data": '
#                              '"model.xgb", "model_class": '
#                              '"xgboost.core.Booster", "model_format": "xgb", '
#                              '"code": null}}, "model_uuid": '
#                              '"c9d25754c7344e44b4e9bb6e28ce3e3d", '
#                              '"mlflow_version": "2.14.3", "model_size_bytes": '
#                              '398095}]',
#  'mlflow.runName': 'spiffy-shrimp-282',
#  'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/m13_2024/experiments/mlruns/1/c0568075b89646b692652e001a39a74a/artifacts', end_time=1721067168679, experiment_id='1', lifecycle_stage='active', run_id='c0568075b89646b692652e001a39a74a', run_name='spiffy-shrimp-282', run_uuid='c0568075b89646b692652e001a39a74a', start_time=1721067165860, status='FAILED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='d4931da7', name='dataset', profile=('{"features_shape": [55463, 5], "features_size": 277315, "features_nbytes": '
#  '1109260}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#  '"/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='train'>]>,
#  <DatasetInput: dataset=<Dataset: digest='5bfd52e6', name='validation', profile=('{"features_shape": [54380, 5], "features_size": 271900, "features_nbytes": '
#  '1087600}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float32\\", \\"shape\\": [-1, 5]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "emelidral", "mlflow.source.name": '
#  '"/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>
# <Run: data=<RunData: metrics={'rmse': 18.019460270301373}, params={'early_stopping_rounds': '50',
#  'max_depth': '26',
#  'num_boost_round': '100',
#  'reg_alpha': '0.34680544527277984'}, tags={'mlflow.runName': 'skittish-cod-953',
#  'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/m13_2024/experiments/mlruns/1/d7972c0e514a4833bf6c127fe38fea18/artifacts', end_time=1721067042252, experiment_id='1', lifecycle_stage='active', run_id='d7972c0e514a4833bf6c127fe38fea18', run_name='skittish-cod-953', run_uuid='d7972c0e514a4833bf6c127fe38fea18', start_time=1721067039164, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[]>>
# <Run: data=<RunData: metrics={'rmse': 18.347664694490177}, params={'early_stopping_rounds': '50',
#  'max_depth': '43',
#  'num_boost_round': '100',
#  'reg_alpha': '0.011082869101940387'}, tags={'mlflow.runName': 'bustling-seal-72',
#  'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/m13_2024/experiments/mlruns/1/2d75d87af3fe4c559c00145ae2cfe881/artifacts', end_time=1721067039153, experiment_id='1', lifecycle_stage='active', run_id='2d75d87af3fe4c559c00145ae2cfe881', run_name='bustling-seal-72', run_uuid='2d75d87af3fe4c559c00145ae2cfe881', start_time=1721067032867, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[]>>
# <Run: data=<RunData: metrics={'rmse': 15.102428116729694}, params={'early_stopping_rounds': '50',
#  'max_depth': '4',
#  'num_boost_round': '100',
#  'reg_alpha': '0.016753683623350845'}, tags={'mlflow.runName': 'zealous-snipe-789',
#  'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/m13_2024/experiments/mlruns/1/2e04b61c569a438fa4321d0762f077d7/artifacts', end_time=1721067032864, experiment_id='1', lifecycle_stage='active', run_id='2e04b61c569a438fa4321d0762f077d7', run_name='zealous-snipe-789', run_uuid='2e04b61c569a438fa4321d0762f077d7', start_time=1721067032432, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[]>>
# <Run: data=<RunData: metrics={'rmse': 18.191008022858792}, params={'early_stopping_rounds': '50',
#  'max_depth': '22',
#  'num_boost_round': '100',
#  'reg_alpha': '0.09021935674093513'}, tags={'mlflow.runName': 'victorious-chimp-213',
#  'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/m13_2024/experiments/mlruns/1/d81c610f0ac543ac81a88ea8b290a933/artifacts', end_time=1721067032422, experiment_id='1', lifecycle_stage='active', run_id='d81c610f0ac543ac81a88ea8b290a933', run_name='victorious-chimp-213', run_uuid='d81c610f0ac543ac81a88ea8b290a933', start_time=1721067029375, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[]>>
# <Run: data=<RunData: metrics={'rmse': 14.63216015221906}, params={'early_stopping_rounds': '50',
#  'max_depth': '6',
#  'num_boost_round': '100',
#  'reg_alpha': '0.23482632306964524'}, tags={'mlflow.runName': 'valuable-shoat-19',
#  'mlflow.source.name': '/opt/homebrew/Caskroom/miniconda/base/envs/m13/lib/python3.11/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'emelidral'}>, info=<RunInfo: artifact_uri='/Users/emelidral/Dev/m13_2024/experiments/mlruns/1/5459119afb674356ac12ce570597bf18/artifacts', end_time=1721067029371, experiment_id='1', lifecycle_stage='active', run_id='5459119afb674356ac12ce570597bf18', run_name='valuable-shoat-19', run_uuid='5459119afb674356ac12ce570597bf18', start_time=1721067028885, status='FINISHED', user_id='emelidral'>, inputs=<RunInputs: dataset_inputs=[]>>

# %%
for run in runs:
    print(f"run_id={run.info.run_id}, rmse={run.data.metrics}")
# Out:
# run_id=1e8c2ca3d01f4a0592a3589818e6504e, rmse={'rmse': 34.90734333193174}
# run_id=156bf8a4b1474266bad2244e85f60161, rmse={'validation-rmse': 3.8391727821808983, 'stopped_iteration': 99.0, 'best_iteration': 55.0}
# run_id=ddf21f2b704447a09222f1288179c56e, rmse={'validation-rmse': 4.0366592713094285}
# run_id=eb5dce3d3d3b4d388ce1ec2892d83611, rmse={'validation-rmse': 3.8391727821808983, 'stopped_iteration': 99.0, 'best_iteration': 55.0}
# run_id=c0568075b89646b692652e001a39a74a, rmse={'validation-rmse': 3.8391727821808983, 'stopped_iteration': 99.0, 'best_iteration': 55.0}
# run_id=d7972c0e514a4833bf6c127fe38fea18, rmse={'rmse': 18.019460270301373}
# run_id=2d75d87af3fe4c559c00145ae2cfe881, rmse={'rmse': 18.347664694490177}
# run_id=2e04b61c569a438fa4321d0762f077d7, rmse={'rmse': 15.102428116729694}
# run_id=d81c610f0ac543ac81a88ea8b290a933, rmse={'rmse': 18.191008022858792}
# run_id=5459119afb674356ac12ce570597bf18, rmse={'rmse': 14.63216015221906}

# %%
for run in runs:
    if 'validation-rmse' in run.data.metrics:
        print(f"run_id={run.info.run_id}, rmse={run.data.metrics['validation-rmse']}")
# Out:
# run_id=156bf8a4b1474266bad2244e85f60161, rmse=3.8391727821808983

# %%
logged_model_id = 'runs:/156bf8a4b1474266bad2244e85f60161/model'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model_id)
